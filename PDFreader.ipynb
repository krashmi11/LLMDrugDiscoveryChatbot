# %%
# !pip -q install tiktoken pypdf InstructorEmbedding faiss-cpu

# %%
# !pip install sentence-transformers==2.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -r /content/drive/MyDrive/Machine\ Learning/LLM/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 43.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 16.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# !pip3 install text_generation

# %%
from langchain_community.embeddings import HuggingFaceInstructEmbeddings

# %%
from InstructorEmbedding import INSTRUCTOR
# Out:
# /usr/local/lib/python3.10/dist-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange

# %%
from langchain.chains import RetrievalQA
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import PyPDFLoader,CSVLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# DirectoryLoader will load the directory of our choice into the loader variable. From the directory we will going to load only that files which ends with .pdf extension

# %%
# loader=DirectoryLoader('/content/drive/MyDrive/Machine Learning/LLM/',glob="./*.pdf",loader_cls=PyPDFLoader)

# %%
# loader=CSVLoader('/content/drive/MyDrive/Machine Learning/LLM/pIC50.csv')

# %%
# import pandas as pd

# # Create data for the DataFrame
# data = {
#     "prompt": ["What is the pIC50 value of compound whose canonical smile is CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1 and also calculates its drug likeness parameter?	", "Prompt 2", "Prompt 3"],
#     "response": ["The molecule CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1 has properties that suggest it may be suitable for oral administration. Number of Hydrogen Bond Donors (HBD): 0 - A low number of HBDs generally translates to better absorption in the gastrointestinal tract. Number of Hydrogen Bond Acceptors (HBA): 6 - While a higher HBA can affect absorption, the value here is within the acceptable range for oral drugs. Molecular Weight (MW): 312.325 - This falls within the ideal range (150-500) for oral bioavailability. LogP: 2.803 - LogP is a measure of lipophilicity (fat solubility). This value indicates moderate lipophilicity, which is desirable for oral drugs. pIc50:6.1249387366083", "Response 2", "Response 3"]
# }

# # Create DataFrame
# df = pd.DataFrame(data)

# # Print the DataFrame
# print(df)

# %%
# df.to_csv("/content/drive/MyDrive/Machine Learning/LLM/bioactivity.csv")

# %% [markdown]
# loading documents from the folder into documnets variable

# %%
loader = CSVLoader(file_path='/content/drive/MyDrive/Machine Learning/LLM/bioactivity.csv',source_column='prompt')
documents=loader.load()

# %%
# text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
# texts=text_splitter.split_documents(documents)

# %% [markdown]
# Splitting text recursively based on characacters until scanning of whole doc is completed. Text is splitting into chuncks of smaller size. Each chunks corresponds to 1000 characters. Every time recursively splitting takes places. Thus every new chunk will contain 200 characters from the previous chunks.

# %%
# # Define the file path for the text file
# text_file_path = '/content/drive/MyDrive/Machine Learning/LLM/acetylcholinesterase_data.txt'

# # Open the text file for writing
# with open(text_file_path, 'w') as file:
#     # Iterate over each document in texts
#     for doc in texts:
#         file.write(str(doc))
#         file.write('\n')

# %%
# def get_text_split(text_file):
#   with open(text_file,'r') as txt:
#     data=txt.read()
#   text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
#   texts=text_splitter.split_text(data)
#   return texts

# %%
# texts=get_text_split('/content/drive/MyDrive/Machine Learning/LLM/acetylcholinesterase_data.txt')

# %%
# texts[0:2]

# %%
# len(texts)

# %% [markdown]
# Lets Start Embedding for documents. Here we are using Instructor Embeddings for our project.

# %% [markdown]
# Using HuggingFaceAPI directly here. Instead of downloading the package we direcly use the model using API. hkunlp/instructor-xl is a pre-trained text embedding model from the Instructor family, developed by researchers at HKUST (Hong Kong University of Science and Technology). It's designed to generate domain-specific and task-aware text embeddings, making it versatile for various NLP applications.

# %% [markdown]
# Using model of Instructor family,like instructor-xl. This model is best not only for embedding but also for various nlp tasks like Question Answering and

# %%
embeddings = HuggingFaceInstructEmbeddings(
    query_instruction="Represent the query for retrieval: "
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# ...

# %%
# text = "This is a test document."
# query_result = embeddings.embed_query(text)

# %% [markdown]
# Facebook AI Similarity Search (Faiss) is a library for efficient similarity search and clustering of dense vectors. It contains algorithms that search in sets of vectors of any size, up to ones that possibly do not fit in RAM. It also contains supporting code for evaluation and parameter tuning.
#
# Similarity Search: Once the index is constructed, FAISS allows for efficient similarity search operations. Given a query vector, FAISS can quickly retrieve the vectors from the dataset that are most similar to the query vector based on a chosen similarity metric (e.g., cosine similarity, Euclidean distance).
#
# Cosine similarity search:In FAISS, cosine similarity can be utilized as the similarity metric when performing similarity search operations, such as k-nearest neighbor (k-NN) search or range search. Given a query vector and a set of indexed vectors, FAISS computes the cosine similarity between the query vector and each indexed vector and returns the most similar vectors based on their cosine similarity scores.

# %%
from langchain_community.vectorstores import FAISS

# %% [markdown]
# embeddings API is converted text into vectors and storing it into FAISS vector store

# %%
db = FAISS.from_documents(documents=documents, embedding=embeddings)

# %%
import faiss

# %% [markdown]
# We can store db at local index so we dont have to create it everytime

# %%
db.save_local( "/content/drive/MyDrive/Machine Learning/LLM/faiss_index")

# %%
new_db = FAISS.load_local("/content/drive/MyDrive/Machine Learning/LLM/faiss_index", embeddings,allow_dangerous_deserialization=True)

# %%
query="What is the pIC50 value of The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1?	"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# db.save_local("faiss_index")
docs = new_db.similarity_search(query)
docs[0]
# Out:
# Document(page_content=": 8\nprompt: What is the pIC50 value of The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1 which contains the The presence of a carbonyl group (C=O) and sulfur atom (S) can affect the molecule's metabolism and interactions with biological systems?\nresponse: The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1 exhibits several promising characteristics for oral administration based on the provided information:\n\nFavorable Hydrogen Bonding:\nDonors (HBD): 0 (low number, generally better for gastrointestinal absorption)\nAcceptors (HBA): 6 (within the acceptable range for oral drugs)\nSuitable Size and Lipophilicity:\nMolecular Weight (MW): 292.364 (falls within the ideal range for oral bioavailability, 150-500)\nLogP: 2.205 (indicates low lipophilicity, which might be on the lower end for optimal oral absorption)\nMolar Refractivity: 78.272 (within a typical range for drug-like molecules)\nPotential Potency: The pro
# ...

# %% [markdown]
# We can also convert the vectorstore into a Retriever class. This allows us to easily use it in other LangChain methods, which largely work with retrievers

# %%
# import textwrap
# def wrap_text_preserve_newlines(text,width=110):
#     lines=text.split("\n")
#     wrapped_line=[textwrap.fill(line,width=width)for line in lines]
#     wrapped_text="\n".join(wrapped_line)
#     return wrapped_text
# def process_llm_response(llm_response):
#     print(wrap_text_preserve_newlines(llm_response['result']))
#     print('\nsources:')
#     for source in llm_response["source_documents"]:
#       print(source.metadata['source'])

# %%
# print(wrap_text_preserve_newlines(str(docs[0].page_content)))

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain import HuggingFaceHub

# %%
from langchain.llms import GooglePalm
api_key="AIzaSyAz1Txmm4raj7MTeYwEyF0SReqQQA-84ng"
llm=GooglePalm(google_api_key=api_key,temperature=0.7)

# %%
retriever = new_db.as_retriever(search_kwargs={"k":3},score_threshold = 0.7)

# %%
docs = retriever.get_relevant_documents(query)
docs
# Out:
# [Document(page_content=": 8\nprompt: What is the pIC50 value of The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1 which contains the The presence of a carbonyl group (C=O) and sulfur atom (S) can affect the molecule's metabolism and interactions with biological systems?\nresponse: The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1 exhibits several promising characteristics for oral administration based on the provided information:\n\nFavorable Hydrogen Bonding:\nDonors (HBD): 0 (low number, generally better for gastrointestinal absorption)\nAcceptors (HBA): 6 (within the acceptable range for oral drugs)\nSuitable Size and Lipophilicity:\nMolecular Weight (MW): 292.364 (falls within the ideal range for oral bioavailability, 150-500)\nLogP: 2.205 (indicates low lipophilicity, which might be on the lower end for optimal oral absorption)\nMolar Refractivity: 78.272 (within a typical range for drug-like molecules)\nPotential Potency: The pr
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""


PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}


from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm=llm,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=True,
                            chain_type_kwargs=chain_type_kwargs)

# %%
chain(query)
# Out:
# {'query': 'What is the pIC50 value of The molecule with the canonical smile COc1ccc(-c2nc(SC)n(C(=O)N(C)C)n2)cc1?\t',
#  'result': '6.097',
# ...

# %%
chain("What is the pIC50 value of compound whose canonical smile is CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1 ?")
# Out:
# {'query': 'What is the pIC50 value of compound whose canonical smile is CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1 ?',
#  'result': 'The pIC50 value of the compound with the canonical smile CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1 is 4.301.',
# ...

# %%
chain("Tell me the Pic50 value of canonical smile CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C and several promising characteristics for oral administration")
# Out:
# {'query': 'Tell me the Pic50 value of canonical smile CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C and several promising characteristics for oral administration',
#  'result': 'The provided pIC50 value for the canonical smile CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C is 6.097, which suggests moderate to high potency.',
# ...

# %%
chain("Which is my favourite color?")
# Out:
# {'query': 'Which is my favourite color?',
#  'result': "I don't know.",
# ...

# %% [markdown]
# chain of question anser is created
